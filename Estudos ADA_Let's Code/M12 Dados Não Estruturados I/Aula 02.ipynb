# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #### Vamos praticar um pouco
# * Escolha uma imagem da internet
# * Salve  a imagem no seu computador
# * Leia a imagem
# * Visualize a imagem
# * Quantos canais existem na imagem?
# * Qual a dimensão da imagem?
# * Passe a imagem para tons de cinza
# * Salve a imagem em tons de cinza no seu computador e exiba essa imagem
# * Bônus: crie um dataset de 5 imagens e repita os passos anteriores

# %%
pa = cv2.imread("datasets/phanton.png")

# %%
pa.shape
# Out:
# (400, 600, 3)

# %%
plt.imshow(pa)

# %%
pa_rgb = cv2.cvtColor(pa, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(pa_rgb)

# %%
pa_gray = cv2.cvtColor(pa, cv2.COLOR_BGR2GRAY)

plt.imshow(pa_gray, cmap="gray");

# %%
cv2.imwrite("datasets/pa.png", pa_gray)
# Out:
# True

# %%
pa1 = cv2.imread("datasets/pa.png")

# %%
plt.imshow(pa1)

# %%
import glob

for i, file in enumerate(glob.glob('datasets/*')):
    img = cv2.imread(file) ### ler a imagem
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img);
    plt.show()
    #img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    #cv2.imwrite(f'datasets/{file}' + str(i) + '.png', img_gray)

# %%
import os

files = os.listdir("datasets")

for i, n in enumerate(files):
    img = cv2.imread(os.path.join("datasets", n))
    print(n)
    plt.imshow(img);
    plt.show()
    #nome = n.split('.')[0]
    #img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    #cv2.imwrite(f'datasets/{nome}' + ("_Gray") + '.png', img_gray)
# Out:
# invocker.jpg
# invocker_Gray.png
# juguer.png
# juguer_Gray.png
# pa.png
# pa_Gray.png
# phanton.png
# phanton_Gray.png
# phoenix.jpg
# phoenix_Gray.png
# templar.jpg
# templar_Gray.png
# wk.jpg
# wk_Gray.png

# %%
files
# Out:
# ['invocker.jpg',
#  'invocker_Gray.png',
#  'juguer.png',
#  'juguer_Gray.png',
#  'pa.png',
#  'pa_Gray.png',
#  'phanton.png',
#  'phanton_Gray.png',
#  'phoenix.jpg',
#  'phoenix_Gray.png',
#  'templar.jpg',
#  'templar_Gray.png',
#  'wk.jpg',
#  'wk_Gray.png']
