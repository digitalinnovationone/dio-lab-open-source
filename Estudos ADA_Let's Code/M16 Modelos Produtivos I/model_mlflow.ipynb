# %% [markdown]
# # MLFlow
#
#
# Precisa de um Banco de Dados SQL (mysql, postgres, sqlite)
#
# ```
# pip install mlflow
#
# sudo apt install sqlite3
#
# ```
#
#
#
# ```
#
# mlflow server --backend-store-uri sqlite:///mlrunsdb.db \
#               --default-artifact-root ./mlflowruns \
#               --host 0.0.0.0 \
#               --port 5000
#
# ```

# %%
import pandas as pd

URL = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'


df = pd.read_csv(URL)

# cols = ['label']

# cols.extend(['feature_'+str(i) for i in range(1,14)])

# df.columns = cols

df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder




X = df.iloc[:, :-1]
y = df['variety']


le = LabelEncoder()
le.fit(y)
y = le.transform(y)

X_train, X_test, y_train, y_test = train_test_split(X,y , test_size=0.3)


X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# %%
import mlflow

DB_URI = 'sqlite:///mlrunsdb.db'
mlflow.set_tracking_uri(DB_URI)

tags = {
    "Módulo":"Modelos Produtivos 1",
    "Turma":815,
    "objeto":'iris'
}
mlflow.set_experiment(experiment_name='Classificação de Flores')
mlflow.set_experiment_tags(tags=tags)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py", line 736, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: no such column: experiments.creation_time
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/db/utils.py", line 98, in make_managed_session
#     Constructs an alembic Config object referencing the specified database and migration script
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 325, in _list_experiments
#     ):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/orm/query.py", line 2772, in all
#     return self._iter().all()
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/orm/query.py", line 2915, in _iter
#     result = self.session.execute(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/orm/session.py", line 1714, in execute
#     result = conn._execute_20(statement, params or {}, execution_options)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1705, in _execute_20
#     return meth(self, args_10style, kwargs_10style, execution_options)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/sql/elements.py", line 333, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1572, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1943, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 2124, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/util/compat.py", line 208, in raise_
#     raise exception
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py", line 736, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) no such column: experiments.creation_time
# [SQL: SELECT experiments.experiment_id AS experiments_experiment_id, experiments.name AS experiments_name, experiments.artifact_location AS experiments_artifact_location, experiments.lifecycle_stage AS experiments_lifecycle_stage, experiments.creation_time AS experiments_creation_time, experiments.last_update_time AS experiments_last_update_time
# FROM experiments
# WHERE experiments.lifecycle_stage IN (?, ?)]
# [parameters: ('active', 'deleted')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_16828/2329562061.py", line 11, in <module>
#     mlflow.set_experiment(experiment_name='Classificação de Flores')
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/fluent.py", line 111, in set_experiment
#     if experiment_id is None:
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/client.py", line 66, in __init__
#     no such service was set, defaults to the tracking uri of the client.
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py", line 51, in __init__
#     self.store
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py", line 55, in store
#     return utils._get_store(self.tracking_uri)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/utils.py", line 188, in _get_store
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/registry.py", line 39, in get_store
#     return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/registry.py", line 49, in _get_store_with_resolved_uri
#     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/utils.py", line 149, in _get_sqlalchemy_store
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 156, in __init__
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 351, in list_experiments
#     experiment = (
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 328, in _list_experiments
#     :param max_results: If passed, specifies the maximum number of experiments desired. If not
#   File "/usr/lib/python3.8/contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/db/utils.py", line 105, in make_managed_session
#     directory under mlflow/alembic if unspecified. TODO: remove this argument in MLflow 1.1, as
# mlflow.exceptions.MlflowException: (sqlite3.OperationalError) no such column: experiments.creation_time
# [SQL: SELECT experiments.experiment_id AS experiments_experiment_id, experiments.name AS experiments_name, experiments.artifact_location AS experiments_artifact_location, experiments.lifecycle_stage AS experiments_lifecycle_stage, experiments.creation_time AS experiments_creation_time, experiments.last_update_time AS experiments_last_update_time
# FROM experiments
# WHERE experiments.lifecycle_stage IN (?, ?)]
# [parameters: ('active', 'deleted')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/core.py", line 720, in lines
#     pieces = self.included_pieces
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/core.py", line 667, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/core.py", line 646, in executing_piece
#     return only(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, confusion_matrix)


def get_metrics(y_test:list, y_pred:list) -> list:
    ac = accuracy_score(y_test, y_pred)
    pr = precision_score(y_test, y_pred, average='weighted')
    rc = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    return [ac, pr, rc, f1]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline



with mlflow.start_run(
    run_name='API',
    description='Classificando Flores com knn',
    tags={"version":"v3","env":"dev"}
) as model_run:


    k = 9
    knn = KNeighborsClassifier(n_neighbors=k)
    model = Pipeline([('scaler',StandardScaler()),('knn',knn)])
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    # mc = confusion_matrix(y_test.values.ravel(), y_pred)
    ac, pr, rc, f1 = get_metrics(y_test, y_pred)


    # mlflow.log_param("k",k)
    # mlflow.log_param("size_train_dataset", len(X_train))
    # mlflow.log_param("size_test_dataset", len(X_test))

    params = {
        "k":k,
        "size_train_dataset": len(X_train),
        "size_test_dataset": len(X_test),
    }

    metrics = {
        "acuracia":ac,
        "precision":pr,
        "recall":rc,
        "f1":f1
    }

    mlflow.log_params(params=params)
    mlflow.log_metrics(metrics=metrics)

    mlflow.sklearn.log_model(model, "model")

    # mlflow.log_metric("acuracia",ac)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py", line 736, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: no such column: experiments.creation_time
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/db/utils.py", line 98, in make_managed_session
#     Constructs an alembic Config object referencing the specified database and migration script
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 325, in _list_experiments
#     ):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/orm/query.py", line 2772, in all
#     return self._iter().all()
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/orm/query.py", line 2915, in _iter
#     result = self.session.execute(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/orm/session.py", line 1714, in execute
#     result = conn._execute_20(statement, params or {}, execution_options)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1705, in _execute_20
#     return meth(self, args_10style, kwargs_10style, execution_options)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/sql/elements.py", line 333, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1572, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1943, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 2124, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/util/compat.py", line 208, in raise_
#     raise exception
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py", line 1900, in _execute_context
#     self.dialect.do_execute(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py", line 736, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) no such column: experiments.creation_time
# [SQL: SELECT experiments.experiment_id AS experiments_experiment_id, experiments.name AS experiments_name, experiments.artifact_location AS experiments_artifact_location, experiments.lifecycle_stage AS experiments_lifecycle_stage, experiments.creation_time AS experiments_creation_time, experiments.last_update_time AS experiments_last_update_time
# FROM experiments
# WHERE experiments.lifecycle_stage IN (?, ?)]
# [parameters: ('active', 'deleted')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_16828/2562599406.py", line 7, in <module>
#     with mlflow.start_run(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/fluent.py", line 278, in start_run
#     )
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/client.py", line 66, in __init__
#     no such service was set, defaults to the tracking uri of the client.
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py", line 51, in __init__
#     self.store
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py", line 55, in store
#     return utils._get_store(self.tracking_uri)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/utils.py", line 188, in _get_store
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/registry.py", line 39, in get_store
#     return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/registry.py", line 49, in _get_store_with_resolved_uri
#     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/utils.py", line 149, in _get_sqlalchemy_store
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 156, in __init__
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 351, in list_experiments
#     experiment = (
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 328, in _list_experiments
#     :param max_results: If passed, specifies the maximum number of experiments desired. If not
#   File "/usr/lib/python3.8/contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/mlflow/store/db/utils.py", line 105, in make_managed_session
#     directory under mlflow/alembic if unspecified. TODO: remove this argument in MLflow 1.1, as
# mlflow.exceptions.MlflowException: (sqlite3.OperationalError) no such column: experiments.creation_time
# [SQL: SELECT experiments.experiment_id AS experiments_experiment_id, experiments.name AS experiments_name, experiments.artifact_location AS experiments_artifact_location, experiments.lifecycle_stage AS experiments_lifecycle_stage, experiments.creation_time AS experiments_creation_time, experiments.last_update_time AS experiments_last_update_time
# FROM experiments
# WHERE experiments.lifecycle_stage IN (?, ?)]
# [parameters: ('active', 'deleted')]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/IPython/core/ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/core.py", line 720, in lines
#     pieces = self.included_pieces
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/core.py", line 667, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/stack_data/core.py", line 646, in executing_piece
#     return only(
#   File "/home/wiltdb_gts/.local/lib/python3.8/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
import mlflow 

mlflow.set_tracking_uri(uri='http://localhost:5000/')

PATH = 'models:/Iris/Production'

loaded_model = mlflow.sklearn.load_model(PATH)

loaded_model.predict(X_val)
# Out:
# array([2, 0, 0, 0, 2, 1, 1, 2, 2, 1, 2, 2, 0, 0, 1, 1, 2, 1, 0, 0, 0, 2,
#        0, 1, 1, 0, 1])

# %%
loaded_model.predict([[5.1,	3.5, 1.4, 0.2]])
# Out:
# /home/wiltdb_gts/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0])

# %%
loaded_model.score(X_val,y_val)
# Out:
# 1.0
