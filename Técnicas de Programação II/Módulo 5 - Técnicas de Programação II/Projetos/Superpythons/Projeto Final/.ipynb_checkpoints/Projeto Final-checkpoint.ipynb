# %% [markdown]
# # Módulo 5 - Técnicas de Programação II | Python
#
# ## Projeto Final - História das Olimpíadas

# %% [markdown]
# Este projeto consiste em uma análise de dados históricos dos jogos olímpicos.
#
# Utilize qualquer uma das bibliotecas estudadas (```matplotlib```, ```seaborn``` e ```plotly```) para realizar as atividades propostas. Não há problema em usar apenas uma para realizar todas as atividades, nem em utilizar cada uma delas em uma atividade diferente - siga suas preferências pessoais!
#
# Utilize os (muitos) parâmetros permitidos por cada função e/ou atributos dos objetos fornecidos pelas bibliotecas para criar uma identidade visual coesa para ser utilizada em todo o projeto. Use títulos, legendas e rótulos nos eixos para deixar os gráficos verdadeiramente informativos. E não se esqueça que a simples escolha das cores a serem utilizadas pode tornar os gráficos ainda mais interessantes!

# %% [markdown]
# ## Metadados:
#
# O arquivo ```athlete_events.csv``` contém 271116 linhas e 15 colunas. Cada linha corresponde a um indivíduo (atleta) que competiu em um evento olímpico individual. Veja a descrição das 15 colunas, a seguir:
#
# - **ID:** Valor único para cada atleta
# - **Name:** Nome do atleta
# - **Sex:** Gênero do atleta (M para masculino e F para feminino)
# - **Age:** Idade do atleta no momento da competição
# - **Height:** Altura do atleta, em centímetros
# - **Weight:** Peso do atleta, em kg
# - **Team:** Nome do time
# - **NOC:** National Olympic Committee (código de 3 letras)
# - **Games:** Ano e temporada dos jogos
# - **Year:** Ano dos jogos
# - **Season:** Temporada dos jogos (summer para verão e winter para inverno)
# - **City:** Cidade em que ocorreu os jogos
# - **Sport:** Esporte praticado pelo atleta
# - **Event:** Categoria/modalidade da competição
# - **Medal:** Medalha adquirida: Gold (ouro), Silver (prata), Bronze ou NA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from matplotlib import pyplot as plt

# %% [markdown]
# ## O Brasil nas olímpiadas
#
# **1.** Crie um DataFrame contendo apenas informações sobre atletas **brasileiros**. Exiba a quantidade de linhas desse novo DataFrame.

# %%
df = pd.read_csv('./data/athlete_events.csv')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df_bra = df[df['NOC']=='BRA']
qtd_linhas = df_bra.shape[0]
print(f'O DataFrame possui {qtd_linhas} linhas.')
df_bra
# Out:
# O DataFrame possui 3848 linhas.
#             ID                        Name Sex   Age  Height  Weight    Team  \
# 665        386             Alexandre Abeid   M  22.0   194.0    92.0  Brazil
# 666        386             Alexandre Abeid   M  26.0   194.0    92.0  Brazil
# 668        388  Abel Carlos da Silva Braga   M  19.0   190.0    73.0  Brazil
# 781        451         Diana Monteiro Abla   F  21.0   175.0    75.0  Brazil
# 1005       565        Glauclio Serro Abreu   M  26.0   185.0    75.0  Brazil
# ...        ...                         ...  ..   ...     ...     ...     ...
# 268652  134400   Maria Jos "Zz" Bertolotti   F  26.0   190.0     NaN  Brazil
# 269745  134976       Sieglinda Lenk Zigler   F  17.0     NaN     NaN  Brazil
# 269899  135037           Moacir Zimmermann   M  32.0   184.0    70.0  Brazil
# 270478  135289        Zzimo Alves Calazans   M  20.0     NaN     NaN  Brazil
# 270789  135423        Ral Benedito Zumbano   M  22.0     NaN     NaN  Brazil
#
# ...

# %% [markdown]
# **2. Será que existe alguma correlação entre a altura do atleta e seu desempenho, para algum esporte? Faça essa análise separadamente para cada gênero, e conclua.**
#
# Gere um ou mais gráficos de sua escolha, em que seja possível comparar as alturas dos atletas de cada esporte, separando-os por gênero. Se necessário, crie colunas ou DataFrames auxiliares.
#
# **Facilitador:** se quiser, analise apenas os esportes em que se tenha ao menos 5 atletas medalhistas e 5 atletas não medalhistas, para facilitar visualizações e conclusões.

# %%
df_bra1 = df_bra.dropna()
df_bra1
# Out:
#             ID                                          Name Sex   Age  \
# 1651       918                           Ademir Roque Kaefer   M  24.0
# 1652       918                           Ademir Roque Kaefer   M  28.0
# 1668       925           Adenzia Aparecida Ferreira da Silva   F  25.0
# 1733       966                                  Daniel Adler   M  26.0
# 1856      1020                  Adriana Aparecida dos Santos   F  25.0
# ...        ...                                           ...  ..   ...
# 267709  133931                      Arthur Nabarrete Zanetti   M  26.0
# 268211  134186              Jos Elias "Z Elias" Moedim Jnior   M  19.0
# 268218  134190  Jos Marco "Z Marco" Nobrega Ferreira de Melo   M  29.0
# 268219  134191                Jos Marcelo "Z Maria" Ferreira   M  22.0
# 268247  134211                        Jos Carlos Cracco Neto   M  22.0
#
#         Height  Weight      Team  NOC        Games  Year  Season  \
# ...

# %%
df_brah = df_bra1[df_bra1['Sex'] =='M']
df_brah
# Out:
#             ID                                          Name Sex   Age  \
# 1651       918                           Ademir Roque Kaefer   M  24.0
# 1652       918                           Ademir Roque Kaefer   M  28.0
# 1733       966                                  Daniel Adler   M  26.0
# 4226      2419                  Aldair Nascimento dos Santos   M  30.0
# 4482      2559                        Alex Sandro Lobo Silva   M  21.0
# ...        ...                                           ...  ..   ...
# 267709  133931                      Arthur Nabarrete Zanetti   M  26.0
# 268211  134186              Jos Elias "Z Elias" Moedim Jnior   M  19.0
# 268218  134190  Jos Marco "Z Marco" Nobrega Ferreira de Melo   M  29.0
# 268219  134191                Jos Marcelo "Z Maria" Ferreira   M  22.0
# 268247  134211                        Jos Carlos Cracco Neto   M  22.0
#
#         Height  Weight      Team  NOC        Games  Year  Season  \
# ...

# %%
df_brah.isnull().any()
# Out:
# ID        False
# Name      False
# Sex       False
# Age       False
# Height    False
# Weight    False
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal     False
# dtype: bool

# %%
df_brah['Sport'].value_counts()
# Out:
# Football            96
# Volleyball          72
# Sailing             30
# Athletics           25
# Basketball          22
# Swimming            17
# Judo                16
# Beach Volleyball    12
# Equestrianism        9
# Canoeing             4
# Boxing               4
# Gymnastics           4
# Shooting             1
# Taekwondo            1
# Name: Sport, dtype: int64

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='Height', data=df_brah)
plt.title('Distribuição por Altura - Masculino',fontsize=25)
plt.xlabel('Altura', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()

# %%
SportXAltura = df_brah['Sport'][df_brah['Height'] < 171.0]
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(SportXAltura)
plt.title('Atletas com Altura menor que 171.0 por Esporte', fontsize=25)
plt.xlabel('Esportes', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
SportXAltura = df_brah['Sport'][df_brah['Height'] > 173.0]
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(SportXAltura)
plt.title('Atletas com Altura maior que 171.0 por Esporte', fontsize=25)
plt.xlabel('Esportes', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
SportXAltura = df_brah['Sport'][df_brah['Height'] == 190.0]
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(SportXAltura)
plt.title('Atletas com Altura 190.0 distribução por esporte', fontsize=25)
plt.xlabel('Esportes', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_brah['Medal'].value_counts()
# Out:
# Bronze    123
# Silver    114
# Gold       76
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_brah['Height'], df_brah['Sport'])
sns.set()
plt.title('Distribução - esporte x altura', fontsize=15)
plt.xlabel('Altura', fontsize=14)
plt.show()

# %% [markdown]
# Analise DataFrame de mulheres

# %%
df_braf = df_bra1[df_bra1['Sex'] =='F']
df_braf
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1668       925  Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
# 1856      1020         Adriana Aparecida dos Santos   F  25.0   180.0    61.0
# 1857      1020         Adriana Aparecida dos Santos   F  29.0   180.0    61.0
# 1863      1023     Adriana "Adrianinha" Moiss Pinto   F  21.0   170.0    65.0
# 4457      2546    Alessandra dos Santos de Oliveira   F  22.0   200.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 253186  126786           Virna Cristine Dantes Dias   F  24.0   185.0    72.0
# 253187  126786           Virna Cristine Dantes Dias   F  29.0   185.0    72.0
# 255807  128070         Walewska Moreira de Oliveira   F  21.0   190.0    73.0
# 255809  128070         Walewska Moreira de Oliveira   F  29.0   190.0    73.0
# 267294  133724         Ilisaine Karen "Zaine" David   F  22.0   190.0    70.0
#
# ...

# %%
df_braf['Sport'].value_counts()
# Out:
# Volleyball           48
# Football             35
# Basketball           24
# Beach Volleyball     13
# Judo                  5
# Sailing               4
# Modern Pentathlon     1
# Taekwondo             1
# Swimming              1
# Boxing                1
# Athletics             1
# Name: Sport, dtype: int64

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(x='Height', data=df_braf)
plt.title('Distribuição por Altura - Feminino', fontsize=25)
plt.xlabel('Altura', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()

# %%
SportXAlturaFem = df_braf['Sport'][df_braf['Height'] < 171.0]
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(SportXAlturaFem)
plt.title('Atletas com Altura menor que 171.0 por Esporte', fontsize=25)
plt.xlabel('Esportes', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
SportXAlturaFem = df_braf['Sport'][df_braf['Height'] > 173.0]
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(SportXAlturaFem)
plt.title('Atletas com Altura maior que 173.0 por Esporte', fontsize=25)
plt.xlabel('Esportes', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_braf['Medal'].value_counts()
# Out:
# Silver    54
# Bronze    49
# Gold      31
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_braf['Height'], df_braf['Sport'])
sns.set()
plt.title('Distribução - esporte x altura', fontsize=15)
plt.xlabel('Altura', fontsize=14)
plt.show()

# %% [markdown]
# **3. Vamos analisar agora as medalhas que nossos atletas trouxeram para casa.**
#
# Crie uma visualização de sua preferência para mostrar, por esporte, a proporção de medalhas de ouro, prata e bronze que nosso país já consquistou.
#
# **Facilitador:** Se preferir, mostre as proporções apenas para os 6 esportes que tiveram mais medalhas.
#
# *DICA:* Cuidado! Esportes em equipe dão medalhas a todos os jogadores, mas só contabilizam uma vez!

# %%
dfa = df_bra1.drop_duplicates(subset=['Year', 'Sport'])
dfa
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1651       918                  Ademir Roque Kaefer   M  24.0   179.0    74.0
# 1652       918                  Ademir Roque Kaefer   M  28.0   179.0    74.0
# 1668       925  Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
# 1733       966                         Daniel Adler   M  26.0   180.0    72.0
# 1856      1020         Adriana Aparecida dos Santos   F  25.0   180.0    61.0
# ...        ...                                  ...  ..   ...     ...     ...
# 194967   97845          Isaquias Queiroz dos Santos   M  22.0   175.0    85.0
# 209232  105049                 Adriana Ramos Samuel   F  30.0   178.0    65.0
# 221565  111358           Maicon de Andrade Siqueira   M  23.0   190.0    90.0
# 263339  131784                    Felipe Almeida Wu   M  24.0   169.0    69.0
# 267707  133931             Arthur Nabarrete Zanetti   M  22.0   156.0    61.0
#
# ...

# %%
goldMedals = dfa[(dfa.Medal == 'Gold')]
goldMedals.head()
# Out:
#         ID                                 Name Sex   Age  Height  Weight  \
# 1668   925  Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
# 4825  2758                 Alison Conte Cerutti   M  30.0   203.0   106.0
# 5930  3330                       Amauri Ribeiro   M  33.0   198.0    87.0
# 6760  3790       Anderson de Oliveira Rodrigues   M  30.0   190.0    95.0
# 9260  5093               William Peixoto Arjona   M  37.0   186.0    78.0
#
#           Team  NOC        Games  Year  Season            City  \
# 1668    Brazil  BRA  2012 Summer  2012  Summer          London
# 4825  Brazil-1  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 5930    Brazil  BRA  1992 Summer  1992  Summer       Barcelona
# 6760    Brazil  BRA  2004 Summer  2004  Summer          Athina
# 9260    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
#
#                  Sport                                    Event Medal
# 1668        Volleyball            Volleyball Women's Volleyball  Gold
# ...

# %%
goldMedals['Sport'].value_counts()
# Out:
# Volleyball          4
# Sailing             4
# Athletics           3
# Equestrianism       1
# Boxing              1
# Swimming            1
# Football            1
# Beach Volleyball    1
# Judo                1
# Gymnastics          1
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(goldMedals['Sport'])
plt.title('Distribuição de Medalhas de Ouro por Esporte',fontsize=25)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
silverMedals = dfa[(dfa.Medal == 'Silver')]
silverMedals.head()
# Out:
#         ID                          Name Sex   Age  Height  Weight    Team  \
# 1651   918           Ademir Roque Kaefer   M  24.0   179.0    74.0  Brazil
# 1652   918           Ademir Roque Kaefer   M  28.0   179.0    74.0  Brazil
# 1733   966                  Daniel Adler   M  26.0   180.0    72.0  Brazil
# 1856  1020  Adriana Aparecida dos Santos   F  25.0   180.0    61.0  Brazil
# 4482  2559        Alex Sandro Lobo Silva   M  21.0   177.0    60.0  Brazil
#
#       NOC        Games  Year  Season         City       Sport  \
# 1651  BRA  1984 Summer  1984  Summer  Los Angeles    Football
# 1652  BRA  1988 Summer  1988  Summer        Seoul    Football
# 1733  BRA  1984 Summer  1984  Summer  Los Angeles     Sailing
# 1856  BRA  1996 Summer  1996  Summer      Atlanta  Basketball
# 4482  BRA  2012 Summer  2012  Summer       London    Football
#
#                                     Event   Medal
# 1651              Football Men's Football  Silver
# ...

# %%
silverMedals['Sport'].value_counts()
# Out:
# Football            4
# Beach Volleyball    4
# Athletics           3
# Volleyball          2
# Swimming            2
# Shooting            1
# Sailing             1
# Basketball          1
# Judo                1
# Gymnastics          1
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(silverMedals['Sport'])
plt.title('Distribuição de Medalhas de Prata por Esporte',fontsize=25)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
bronzeMedals = dfa[(dfa.Medal == 'Bronze')]
bronzeMedals.head()
# Out:
#         ID                                           Name Sex   Age  Height  \
# 1857  1020                   Adriana Aparecida dos Santos   F  29.0   180.0
# 4226  2419                   Aldair Nascimento dos Santos   M  30.0   183.0
# 4561  2592  Alexandre "Alexandre Pato" Rodrigues da Silva   M  18.0   179.0
# 4642  2648                      Zenny "Algodo" de Azevedo   M  23.0   183.0
# 4645  2648                      Zenny "Algodo" de Azevedo   M  35.0   183.0
#
#       Weight    Team  NOC        Games  Year  Season     City       Sport  \
# 1857    61.0  Brazil  BRA  2000 Summer  2000  Summer   Sydney  Basketball
# 4226    76.0  Brazil  BRA  1996 Summer  1996  Summer  Atlanta    Football
# 4561    71.0  Brazil  BRA  2008 Summer  2008  Summer  Beijing    Football
# 4642    77.0  Brazil  BRA  1948 Summer  1948  Summer   London  Basketball
# 4645    77.0  Brazil  BRA  1960 Summer  1960  Summer     Roma  Basketball
#
#                               Event   Medal
# ...

# %%
bronzeMedals['Sport'].value_counts()
# Out:
# Judo                 7
# Athletics            7
# Sailing              6
# Swimming             5
# Basketball           4
# Football             2
# Volleyball           2
# Equestrianism        2
# Boxing               2
# Taekwondo            2
# Modern Pentathlon    1
# Canoeing             1
# Beach Volleyball     1
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(bronzeMedals['Sport'])
plt.title('Distribuição de Medalhas de Bronze por Esporte', fontsize=25)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.figure(figsize=(20, 10))
plt.tight_layout()
dfa.groupby('Sport')[u'Medal'].value_counts().plot.bar()
plt.title('Distribuição de Medalhas por Esporte',fontsize=25)
plt.xlabel('Esporte e Medalhas', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()

# %%
dfa.Sport.value_counts().reset_index(name='Medal')
# Out:
#                 index  Medal
# 0           Athletics     13
# 1             Sailing     11
# 2                Judo      9
# 3          Volleyball      8
# 4            Swimming      8
# 5            Football      7
# 6    Beach Volleyball      6
# 7          Basketball      5
# 8       Equestrianism      3
# 9              Boxing      3
# 10          Taekwondo      2
# 11         Gymnastics      2
# 12  Modern Pentathlon      1
# 13           Canoeing      1
# 14           Shooting      1

# %% [markdown]
# **4. Para finalizar a história do Brasil, vamos ver a série temporal de medalhas brasileiras.**
#
# Crie um gráfico de sua escolha, que mostre o total de medalhas de ouro, prata e bronze, por edição da olimpíada (em ordem cronológica).
#
# *DICA:* Mais uma vez, tome cuidado com os esportes em grupo - os contabilize apenas uma vez!

# %%
fig = px.bar(dfa, x='Games', color='Medal', barmode='group', labels={
    'Games': 'Edição da olimpíada',
    'count': 'Quantidade'
} , template='plotly_white') #['stack', 'group', 'overlay', 'relative']
fig.update_layout(title={
    'text' : 'Total de medalhas por edição da Olimpíada',
    'y': 0.9,
    'x': 0.5
})

fig.show()
# Out:
# <div>                            <div id="70732dd8-da82-4e93-9f27-0494327d0dc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70732dd8-da82-4e93-9f27-0494327d0dc2")) {                    Plotly.newPlot(                        "70732dd8-da82-4e93-9f27-0494327d0dc2",                        [{"alignmentgroup":"True","hovertemplate":"Medal=Silver<br>Edi\u00e7\u00e3o da olimp\u00edada=%{x}<br>Quantidade=%{y}<extra></extra>","legendgroup":"Silver","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Silver","offsetgroup":"Silver","orientation":"v","showlegend":true,"textposition":"auto","x":["1984 Summer","1988 Summer","1984 Summer","1996 Summer","2012 Summer","2004 Summer","2012 Summer","1984 Summer","2008 Summer","2000 Summer","2004 Summer","19
# ...

# %% [markdown]
# **5. Agora é com vocês!**
#
# Escolha uma análise visual que julga interessante de fazer neste conjunto de dados, faça o(s) gráficos(s) necessários e comente os resultados.

# %%
gold = df[df['Medal']=='Gold']
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(gold['Age'])
plt.title('Distribuição de medalhas de ouro por idade', fontsize=25)
plt.xlabel('Idade', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()
# Out:
# C:\Users\Paula\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
female_all = df[(df.Sex == 'F') & (df.Season == 'Summer')]
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', data=female_all)
plt.title('Medalhas femininas por edição dos Jogos de verão', fontsize=25)
plt.xlabel('Anos', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()

# %%
fig = px.bar(dfa, x='Sport', color='Sex', barmode='group',labels={
    'Games': 'Edição da olimpíada',
    'count': 'Quantidade'
} , template='plotly_white') #['stack', 'group', 'overlay', 'relative']
fig.update_layout(title={
    'text' : 'Distribuição de medalhas por Sexo - Brasil',
    'y': 0.9,
    'x': 0.5
})  #['stack', 'group', 'overlay', 'relative']

fig.show()
# Out:
# <div>                            <div id="bfde1808-e419-41a0-a9ad-52a3d62a6f40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfde1808-e419-41a0-a9ad-52a3d62a6f40")) {                    Plotly.newPlot(                        "bfde1808-e419-41a0-a9ad-52a3d62a6f40",                        [{"alignmentgroup":"True","hovertemplate":"Sex=M<br>Sport=%{x}<br>Quantidade=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["Football","Football","Sailing","Football","Football","Football","Basketball","Basketball","Beach Volleyball","Beach Volleyball","Volleyball","Volleyball","Basketball","Volleyball","Volleyball","Volleyball","
# ...

# %%
plt.figure(figsize=(20, 10))
plt.tight_layout()
dfa.groupby('Sport')[u'Sex'].value_counts().plot.bar()
plt.title('Distribuição de Medalhas por Esporte e Sex - Exemplo 2 ', fontsize=25)
plt.xlabel('Esporte e Sexo', fontsize=19)
plt.ylabel('Quantidade', fontsize=19)
plt.show()

# %%
gold = gold[gold['Medal']=='Gold']
country_list=['USA', 'URS', 'ITA','GBR','GER']
gold = gold[gold['NOC'].isin(country_list)]

# %%
a=gold[['NOC','Year']].value_counts().reset_index(name='Medal')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data =a, x = 'Year', y= 'Medal',hue="NOC")
plt.show()
